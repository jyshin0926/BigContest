# %%
# !pip install plotly
# Out:
# Collecting plotly
#   Downloading plotly-4.10.0-py2.py3-none-any.whl (13.0 MB)
#      |████████████████████████████████| 13.0 MB 7.9 MB/s eta 0:00:01
# Collecting retrying>=1.3.3
#   Downloading retrying-1.3.3.tar.gz (10 kB)
# Requirement already satisfied: six in /Users/jaeyoungshin/opt/anaconda3/lib/python3.8/site-packages (from plotly) (1.15.0)
# Building wheels for collected packages: retrying
#   Building wheel for retrying (setup.py) ... done
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11430 sha256=3b1e070d6b7883d1bf29cea65e9288aba3eb1716cddb4607fc36c913dc6137ec
#   Stored in directory: /Users/jaeyoungshin/Library/Caches/pip/wheels/c4/a7/48/0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# Installing collected packages: retrying, plotly
# Successfully installed plotly-4.10.0 retrying-1.3.3

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib import font_manager,rc,style
import seaborn as sns
style.use('ggplot')
plt.rc('font',family='AppleGothic')
plt.rc('axes', unicode_minus=False)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# 앱 순위를 크롤링 사이트: 모바일 인덱스<br>
# 기간 : 2019년 1월 ~ 12월 / 2020년 1월 ~ 9월<br>
# 기간별 어플 순위 / 구글 플레이 스토어(안드로이드) 데이터를 크롤링

# %%
appRank_free_playstore_19_df = pd.read_csv('/Users/jaeyoungshin/Desktop/빅콘/pickle파일모음/covid19_visualize/Crawling/csv/appRank_free_playstore_2019.csv')
appRank_free_playstore_20_df = pd.read_csv('/Users/jaeyoungshin/Desktop/빅콘/pickle파일모음/covid19_visualize/Crawling/csv/appRank_free_playstore_2020.csv')

# %%
fp19 = appRank_free_playstore_19_df.drop(['Unnamed: 0'],axis=1)
fp20 = appRank_free_playstore_20_df.drop(['Unnamed: 0'],axis=1)

# %%
fp19.to_pickle('appRank_free_playstore_19_df.pkl')
fp20.to_pickle('appRank_free_playstore_20_df.pkl')

# %%
fp19 = pd.read_pickle('appRank_free_playstore_19_df.pkl')
fp20 = pd.read_pickle('appRank_free_playstore_20_df.pkl')

# %% [markdown]
# 19년의 건강/운동 항목에는 어떤 어플이 유행했을까?<br>
# * 8월 Mi Fit
# * 10월 ANT+ Plugins Service
# * 11월 ANT+ Plugins Service
#
# 20년의 건강/운동 항목에는 어떤 어플이 해당될까?<br>
# * 코로나맵 - 신종 코로나 바이러스 현황 (2월)
# * 코로나맵 - 코로나알리미 (2월)
# * 굿닥 – 마스크스캐너, 병원 약국 찾기 (3월)
# * 전자출입명부(시설용) 보건복지부 (6월)
# * 전자출입명부(시설용) 보건복지부 (8월)
# * 건강상태 자가진단(교육부) (9월)
# * 질병관리본부 예방접종도우미(9월)
#
# **19년도와는 달리 미용 목적의 건강/운동 항목이 아니라 코로나와 건강, 질병 관련 어플들이 랭킹에 올라와있음을 확인 가능**<br>
# **꾸준히 관심이 지속되고 있음도 확인 가능**<br>
# **자가진단, 예방접종도우미 어플 : 코로나가 장기화됨에 따라 현재는 단순 현황 뿐 아니라 개인의 건강을 직접 체크하고 예방하려는 양상이 보인다.**<br>
#
# 20년에 등장한 의료 항목에는 어떤 어플이 있을까?<br>
# * 코백-코로나 100m 근접시 푸시알림, 확진자 경로추적, 코로나19,  우한폐렴 정보서비스
# * 코로나 알리미 - 우한 폐렴, 코로나 바이러스, 중국 폐렴, 바이러스
# * 의료 어플은 현재까지 20년 월별 50위 랭킹 순위에 있는 건 이 두 개밖에 없고, 2월에만 등장

# %%
fp20
# Out:
#                                                  20_1      20_1_gen  \
# 0                                             국세청 홈택스            도구
# 1                                           Instagram            소셜
# 2                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 3                                             NH스마트뱅킹            금융
# 4                                        쿠팡 (Coupang)            쇼핑
# 5                                  (New) 우리은행 우리WON뱅킹            금융
# 6                                         네이버 - NAVER       도서/참고자료
# 7                                      카카오톡 KakaoTalk        커뮤니케이션
# 8                                       Netflix(넷플릭스)        엔터테인먼트
# 9                                  V3 Mobile Plus 2.0            도구
# 10                        Samsung Smart Switch Mobile            도구
# 11                                                 토스            금융
# 12                              지그재그 - No.1 여성쇼핑몰 모음앱            쇼핑
# 13                                              배달요기요           식음료
# 14                                              배달의민족           식음료
# 15                                             스마트위택스            금융
# 16                         트립스토어 - 해외 패키지 & 에어텔 특가 비교     여행 및 지역정보
# 17                                     Wish - 쇼핑은 즐겁다            쇼핑
# 18                                      네이버 지도, 내비게이션     여행 및 지역정보
# 19                                 Samsung Pay(삼성 페이)        라이프스타일
# 20                                  카카오뱅크 - 같지만 다른 은행            금융
# 21                                    에이블리 - 셀럽마켓 모음앱            쇼핑
# 22                                              카카오내비      지도/내비게이션
# 23                                     Google Play 게임        엔터테인먼트
# 24  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 25   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 26                                           Facebook            소셜
# 27                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 28                                                 밴드            소셜
# 29                                       정부24(구 민원24)           생산성
# 30                           wavve(웨이브) - 재미의 파도를 타다!        엔터테인먼트
# 31                                        KB국민은행 스타뱅킹            금융
# 32                                       한컴오피스 viewer           생산성
# 33                               터치엔 엠백신 for Web(기업용)            금융
# 34                                           롯데마트 M쿠폰            쇼핑
# 35                                          TikTok 틱톡  동영상 플레이어/편집기
# 36                                 T map - 내비게이션 / 지도      지도/내비게이션
# 37                                            ISP/페이북            금융
# 38                               i-ONE Bank - IBK기업은행            금융
# 39                                               삼성카드            금융
# 40                            휴대폰 인증서 서비스(유비키_UBIKey)            금융
# 41                                   SERIES - 네이버 시리즈       도서/참고자료
# 42                     오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 43                                          바이오인증 공동앱            금융
# 44                                   네이버 파파고 - AI 통번역            도구
# 45                                              NH콕뱅크            금융
# 46                              다방 - 대한민국 부동산 매물 최다보유    부동산/홈 인테리어
# 47                                    브랜디 - 여성들의 쇼핑맛집            쇼핑
# 48                파일썬 공식앱 - 최신영화,드라마,예능,애니,웹툰 무료 다시보기        엔터테인먼트
# 49                            신한 쏠(SOL) – 신한은행 스마트폰뱅킹            금융
#
#                                                  20_2    20_2_gen  \
# 0                                               우체국쇼핑          쇼핑
# 1   코백-코로나 100m 근접시 푸시알림, 확진자 경로추적, 코로나19,  우한폐렴 정...          의료
# 2                                        공영쇼핑 - 공영홈쇼핑          쇼핑
# 3                                        Forest: 집중하기         생산성
# 4                               코로나맵 - 신종 코로나 바이러스 현황       건강/운동
# 5                                               Amway        비즈니스
# 6                                           Instagram          소셜
# 7                                            대한민국 청와대         생산성
# 8                                                 농협몰          쇼핑
# 9                                      Wish - 쇼핑은 즐겁다          쇼핑
# 10                     Android Auto - 호환되는 차량 및 헤드유닛용         자동차
# 11                           당근마켓 - 우리 동네 중고 직거래 벼룩장터          쇼핑
# 12                                       쿠팡 (Coupang)          쇼핑
# 13                                      Netflix(넷플릭스)      엔터테인먼트
# 14                                        네이버 - NAVER     도서/참고자료
# 15                                            신천지위치알림      라이프스타일
# 16                        Samsung Smart Switch Mobile          도구
# 17                                     카카오톡 KakaoTalk      커뮤니케이션
# 18                                                우체국      라이프스타일
# 19                                                 리브          금융
# 20                                             농협하나로앱      라이프스타일
# 21                                           삼성 음성 녹음          도구
# 22                                              배달의민족         식음료
# 23                                 V3 Mobile Plus 2.0          도구
# 24                                              배달요기요         식음료
# 25                                ZOOM Cloud Meetings        비즈니스
# 26                                Android 시스템 WebView          도구
# 27                     오늘의집 - 700만이 선택한 No.1 인테리어 필수앱  부동산/홈 인테리어
# 28  미스터트롯 무료듣기 – 미스터트롯 트로트 메들리 – 미스터트롯 방송영상, 예선 참가...      음악/오디오
# 29                                         SEIO Agent          도구
# 30                                     Google Play 게임      엔터테인먼트
# 31                                       한컴오피스 viewer         생산성
# 32                                           Facebook          소셜
# 33                                            NH스마트뱅킹          금융
# 34                  미스터트롯 임영웅 노래모음 무료 - 임영웅 콘서트,방송,노래      음악/오디오
# 35                                                 토스          금융
# 36               위메프 - 특가대표 (특가 / 쇼핑 / 쇼핑앱 / 쿠폰 / 배송)          쇼핑
# 37             코로나 알리미 - 우한 폐렴, 코로나 바이러스, 중국 폐렴, 바이러스          의료
# 38                                                 밴드          소셜
# 39                            키즈노트::유치원,어린이집,학원 필수 앱!      커뮤니케이션
# 40                        AliExpress - 스마트한쇼핑, 더즐거운생활          쇼핑
# 41                                  카카오뱅크 - 같지만 다른 은행          금융
# 42   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )   여행 및 지역정보
# 43                                           타임커머스 티몬          쇼핑
# 44                                 (New) 우리은행 우리WON뱅킹          금융
# 45                         아이디어스(idus) - 핸드메이드/수공예 장터          쇼핑
# 46                                                청약홈          금융
# 47                                               삼성카드          금융
# 48                                      코로나맵 - 코로나알리미       건강/운동
# 49                                    에이블리 - 셀럽마켓 모음앱          쇼핑
#
#                                                  20_3      20_3_gen  \
# 0                                              경기지역화폐            금융
# 1                                 ZOOM Cloud Meetings          비즈니스
# 2                                       Netflix(넷플릭스)        엔터테인먼트
# 3                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 4                                           Instagram            소셜
# 5                                         네이버 - NAVER       도서/참고자료
# 6                                               배달의민족           식음료
# 7                         Samsung Smart Switch Mobile            도구
# 8                      오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 9                                      카카오톡 KakaoTalk        커뮤니케이션
# 10                                       쿠팡 (Coupang)            쇼핑
# 11                                              배달요기요           식음료
# 12                              지그재그 - No.1 여성쇼핑몰 모음앱            쇼핑
# 13                                       한컴오피스 viewer           생산성
# 14                                 V3 Mobile Plus 2.0            도구
# 15                                    에이블리 - 셀럽마켓 모음앱            쇼핑
# 16                                                 밴드            소셜
# 17                         아이디어스(idus) - 핸드메이드/수공예 장터            쇼핑
# 18                                                 토스            금융
# 19                                     Google Play 게임        엔터테인먼트
# 20                                 텔레그램 공식 앱 Telegram        커뮤니케이션
# 21                         PASS by SK TELECOM(구, T인증)            금융
# 22  임영웅 무료듣기 – 미스터트롯 임영웅 메들리 – 미스터트롯 임영웅 방송, 예선 참가...        음악/오디오
# 23   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 24                                             EBS 초등            교육
# 25                                PASS by U+(구, U+인증)            금융
# 26                                           Facebook            소셜
# 27                                      네이버 지도, 내비게이션     여행 및 지역정보
# 28                    티빙(TVING) - 실시간TV, 방송VOD, 영화VOD  동영상 플레이어/편집기
# 29                                  카카오뱅크 - 같지만 다른 은행            금융
# 30                                          TikTok 틱톡  동영상 플레이어/편집기
# 31  미스터트롯 무료듣기 – 미스터트롯 트로트 메들리 – 미스터트롯 방송영상, 예선 참가...        음악/오디오
# 32                                     Wish - 쇼핑은 즐겁다            쇼핑
# 33                                               올리브영            쇼핑
# 34                              하이클래스-알림장, 가정통신문, 하이톡            교육
# 35                                      클래스팅 - 학교 플랫폼            교육
# 36                                            ISP/페이북            금융
# 37                                           삼성 음성 녹음            도구
# 38                                           SNOW 스노우            사진
# 39                                   SERIES - 네이버 시리즈       도서/참고자료
# 40                                     스마트 공지시스템 e알리미        커뮤니케이션
# 41                                 T map - 내비게이션 / 지도      지도/내비게이션
# 42                                            NH스마트뱅킹            금융
# 43                              굿닥 – 마스크스캐너, 병원 약국 찾기         건강/운동
# 44                                       정부24(구 민원24)           생산성
# 45                           wavve(웨이브) - 재미의 파도를 타다!        엔터테인먼트
# 46                  미스터트롯 임영웅 노래모음 무료 - 임영웅 콘서트,방송,노래        음악/오디오
# 47                                                 멜론        음악/오디오
# 48                                          키움증권 계좌개설            금융
# 49                                             부산 동백전            금융
#
#                                                  20_4      20_4_gen  \
# 0                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 1                                             국세청 홈택스            도구
# 2                      Android Auto - 호환되는 차량 및 헤드유닛용           자동차
# 3                              Google Duo - 고화질 화상 통화        커뮤니케이션
# 4                                           내 곁에 국민연금            금융
# 5                                 ZOOM Cloud Meetings          비즈니스
# 6                                           Instagram            소셜
# 7                                              경기지역화폐            금융
# 8                                       Netflix(넷플릭스)        엔터테인먼트
# 9                                      카카오톡 KakaoTalk        커뮤니케이션
# 10                                        네이버 - NAVER       도서/참고자료
# 11                                Android 시스템 WebView            도구
# 12                                       쿠팡 (Coupang)            쇼핑
# 13                          사용자 휴대폰 도우미 - Windows와 연결           생산성
# 14                     오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 15                                 V3 Mobile Plus 2.0            도구
# 16                                         SEIO Agent            도구
# 17                                       한컴오피스 viewer           생산성
# 18                        Samsung Smart Switch Mobile            도구
# 19                                                 밴드            소셜
# 20                                            비플 제로페이            금융
# 21                                                 토스            금융
# 22                                          TikTok 틱톡  동영상 플레이어/편집기
# 23                                            모바일 관세청          비즈니스
# 24                                              배달의민족           식음료
# 25             롯데 ON - 롯데닷컴 (Lotte.com 롯데,백화점,홈쇼핑,쇼핑)            쇼핑
# 26                                      네이버 지도, 내비게이션     여행 및 지역정보
# 27                                            NH스마트뱅킹            금융
# 28                         PASS by SK TELECOM(구, T인증)            금융
# 29                                        티머니페이(BETA)            금융
# 30                                               할인중독            쇼핑
# 31                                           삼성 음성 녹음            도구
# 32                                              배달요기요           식음료
# 33                                 T map - 내비게이션 / 지도      지도/내비게이션
# 34                                             V LIVE        엔터테인먼트
# 35  임영웅 무료듣기 – 미스터트롯 임영웅 메들리 – 미스터트롯 임영웅 방송, 예선 참가...        음악/오디오
# 36                         아이디어스(idus) - 핸드메이드/수공예 장터            쇼핑
# 37                                  카카오뱅크 - 같지만 다른 은행            금융
# 38                                       정부24(구 민원24)           생산성
# 39                                     Google Play 게임        엔터테인먼트
# 40                                               삼성카드            금융
# 41                               터치엔 엠백신 for Web(기업용)            금융
# 42                                                청약홈            금융
# 43                                          KT 금융유심관리            금융
# 44                                           Facebook            소셜
# 45   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 46                                                 멜론        음악/오디오
# 47                                           핀크 Finnq            금융
# 48                                               공구마켓            쇼핑
# 49                                            4shared        엔터테인먼트
#
#                                                  20_5      20_5_gen  \
# 0                                           TikTok 틱톡  동영상 플레이어/편집기
# 1                                             국세청 홈택스            도구
# 2   하루날씨 - 한눈에 필수 정보 AI안내, 첫화면, 실시간, 예보, 미세먼지, WHO...            날씨
# 3                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 4                                         네이버 - NAVER       도서/참고자료
# 5                                         KB국민은행 스타뱅킹            금융
# 6                                      카카오톡 KakaoTalk        커뮤니케이션
# 7                         Samsung Smart Switch Mobile            도구
# 8                                  V3 Mobile Plus 2.0            도구
# 9                                 ZOOM Cloud Meetings          비즈니스
# 10                                      Netflix(넷플릭스)        엔터테인먼트
# 11                                          Instagram            소셜
# 12                                           제이티아이알리미        라이프스타일
# 13                                       한컴오피스 viewer           생산성
# 14                     Android Auto - 호환되는 차량 및 헤드유닛용           자동차
# 15                         PASS by SK TELECOM(구, T인증)            금융
# 16                                      네이버 지도, 내비게이션     여행 및 지역정보
# 17                                       쿠팡 (Coupang)            쇼핑
# 18                                              배달의민족           식음료
# 19                                            모바일 관세청          비즈니스
# 20                     오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 21                    파도 MP3 무료 음악 다운, PADO MP3 노래 다운        음악/오디오
# 22                                                 토스            금융
# 23                                            NH스마트뱅킹            금융
# 24                                 T map - 내비게이션 / 지도      지도/내비게이션
# 25                                                농협몰            쇼핑
# 26                                                 밴드            소셜
# 27                                               VITA  동영상 플레이어/편집기
# 28                                               삼성카드            금융
# 29                   실시간 무료 TV - 지상파, 종합편성, 케이블 무료 티비  동영상 플레이어/편집기
# 30                                    에이블리 - 셀럽마켓 모음앱            쇼핑
# 31   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 32                                              배달요기요           식음료
# 33                                           FLO – 플로        음악/오디오
# 34                                  카카오뱅크 - 같지만 다른 은행            금융
# 35                                            4shared        엔터테인먼트
# 36                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 37                                           Facebook            소셜
# 38                                              NH콕뱅크            금융
# 39                                       정부24(구 민원24)           생산성
# 40                                               온통대전            금융
# 41                               터치엔 엠백신 for Web(기업용)            금융
# 42                                              신한페이판            금융
# 43                             네이버 웹툰 - Naver Webtoon            만화
# 44                                               스타벅스        엔터테인먼트
# 45                                              카카오내비      지도/내비게이션
# 46                                                 멜론        음악/오디오
# 47                                     Google Play 게임        엔터테인먼트
# 48                                     Wish - 쇼핑은 즐겁다            쇼핑
# 49                            신한 쏠(SOL) – 신한은행 스마트폰뱅킹            금융
#
#                                                  20_6      20_6_gen  \
# 0                                           TikTok 틱톡  동영상 플레이어/편집기
# 1                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 2                                       Clean Booster            도구
# 3                                             FaceApp            사진
# 4                                       Netflix(넷플릭스)        엔터테인먼트
# 5                      오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 6                                      Action Cleaner            도구
# 7                         Samsung Smart Switch Mobile            도구
# 8                                      카카오톡 KakaoTalk        커뮤니케이션
# 9                                 ZOOM Cloud Meetings          비즈니스
# 10                                        네이버 - NAVER       도서/참고자료
# 11                                          Instagram            소셜
# 12                              한국 속보 : 최신 지역 뉴스 및 속보         뉴스/잡지
# 13                                              배달의민족           식음료
# 14                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 15                          T연락처 - 주소록 실시간 백업, 114 검색            도구
# 16                                                 토스            금융
# 17                                         Fast Clean            도구
# 18                                              배달요기요           식음료
# 19                         PASS by SK TELECOM(구, T인증)            금융
# 20                                       쿠팡 (Coupang)            쇼핑
# 21                                            모바일 관세청          비즈니스
# 22                                 T map - 내비게이션 / 지도      지도/내비게이션
# 23                       Monster School for Minecraft        엔터테인먼트
# 24                   실시간 무료 TV - 지상파, 종합편성, 케이블 무료 티비  동영상 플레이어/편집기
# 25                                      네이버 지도, 내비게이션     여행 및 지역정보
# 26                                 V3 Mobile Plus 2.0            도구
# 27                                               VITA  동영상 플레이어/편집기
# 28                             쿠팡이츠 - 맛있는 음식을 빠르고 편하게           식음료
# 29                                               할인중독            쇼핑
# 30                    파도 MP3 무료 음악 다운, PADO MP3 노래 다운        음악/오디오
# 31                                    에이블리 - 셀럽마켓 모음앱            쇼핑
# 32                                              카카오내비      지도/내비게이션
# 33                                       한컴오피스 viewer           생산성
# 34                                PASS by U+(구, U+인증)            금융
# 35                    Bigo Live (비고라이브) – 라이브방송, 영상채팅            소셜
# 36                                               스타벅스        엔터테인먼트
# 37   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 38                     번개장터 - 모바일 최대 중고마켓 앱(중고나라,중고차)            쇼핑
# 39     야놀자 - 국내 및 해외 호텔, 모텔, 펜션, 게하, 레저/티켓, 최대 80% 할인     여행 및 지역정보
# 40                                 QR & 바코드 스캐너 (한국어)           생산성
# 41                    SODA 소다 - Natural Beauty Camera            사진
# 42               위메프 - 특가대표 (특가 / 쇼핑 / 쇼핑앱 / 쿠폰 / 배송)            쇼핑
# 43                                           FLO – 플로        음악/오디오
# 44                                                 밴드            소셜
# 45                                       AI 토익 튜터, 산타            교육
# 46                                       마켓컬리-내일의 장보기           식음료
# 47                           wavve(웨이브) - 재미의 파도를 타다!        엔터테인먼트
# 48  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 49                                  전자출입명부(시설용) 보건복지부         건강/운동
#
#                                                  20_7      20_7_gen  \
# 0                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 1                                           TikTok 틱톡  동영상 플레이어/편집기
# 2                      오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 3                                       Netflix(넷플릭스)        엔터테인먼트
# 4                                 ZOOM Cloud Meetings          비즈니스
# 5                         Samsung Smart Switch Mobile            도구
# 6                                      카카오톡 KakaoTalk        커뮤니케이션
# 7             여기어때 - 호텔, 모텔, 펜션, 캠핑, 게하, 액티비티 최저가 예약!     여행 및 지역정보
# 8                                                  토스            금융
# 9                                  V3 Mobile Plus 2.0            도구
# 10     야놀자 - 국내 및 해외 호텔, 모텔, 펜션, 게하, 레저/티켓, 최대 80% 할인     여행 및 지역정보
# 11                                          Instagram            소셜
# 12                                       쿠팡 (Coupang)            쇼핑
# 13                                              배달의민족           식음료
# 14                                        네이버 - NAVER       도서/참고자료
# 15                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 16                             쿠팡이츠 - 맛있는 음식을 빠르고 편하게           식음료
# 17                                    에이블리 - 셀럽마켓 모음앱            쇼핑
# 18   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 19                                               할인중독            쇼핑
# 20                                               코레일톡     여행 및 지역정보
# 21                                 Q-Net 큐넷(자격의 모든 것)            교육
# 22                                 T map - 내비게이션 / 지도      지도/내비게이션
# 23                                      네이버 지도, 내비게이션     여행 및 지역정보
# 24                첫화면 날씨 - 실시간 날씨, 미세먼지, 일기 예보, WHO기준            날씨
# 25                                               VITA  동영상 플레이어/편집기
# 26                                 (New) 우리은행 우리WON뱅킹            금융
# 27                                       한컴오피스 viewer           생산성
# 28                                            NH스마트뱅킹            금융
# 29                   실시간 무료 TV - 지상파, 종합편성, 케이블 무료 티비  동영상 플레이어/편집기
# 30                             이마트 - 매장에서 즐기는 스마트한 혜택        라이프스타일
# 31                                              배달요기요           식음료
# 32  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 33                                일기 예보 2020 - 실시간 날씨            날씨
# 34                     번개장터 - 모바일 최대 중고마켓 앱(중고나라,중고차)            쇼핑
# 35                                         델피노 인증서 복사            금융
# 36                                              카카오내비      지도/내비게이션
# 37                                  카카오뱅크 - 같지만 다른 은행            금융
# 38                                               삼성카드            금융
# 39                                       마켓컬리-내일의 장보기           식음료
# 40                                          키움증권 계좌개설            금융
# 41                                             스마트위택스            금융
# 42                                 QR & 바코드 스캐너 (한국어)           생산성
# 43                                              카카오페이            금융
# 44                                          키움증권 영웅문S            금융
# 45                                               스타벅스        엔터테인먼트
# 46                                     Wish - 쇼핑은 즐겁다            쇼핑
# 47                               터치엔 엠백신 for Web(기업용)            금융
# 48                                                 밴드            소셜
# 49                                       정부24(구 민원24)           생산성
#
#                                                  20_8      20_8_gen  \
# 0                                 ZOOM Cloud Meetings          비즈니스
# 1                                               BBQ치킨           식음료
# 2                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 3                                           TikTok 틱톡  동영상 플레이어/편집기
# 4                                       Netflix(넷플릭스)        엔터테인먼트
# 5                                               배달의민족           식음료
# 6                          Windy.com - 바람, 파도 및 태풍 예보            날씨
# 7                                               하나알리미            금융
# 8                                   전자출입명부(시설용) 보건복지부         건강/운동
# 9                      오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 10                        Samsung Smart Switch Mobile            도구
# 11                                                 토스            금융
# 12                                           행아웃 Meet           생산성
# 13                                 한국투자증권 (스마트폰 계좌개설)            금융
# 14                             쿠팡이츠 - 맛있는 음식을 빠르고 편하게           식음료
# 15                                       쿠팡 (Coupang)            쇼핑
# 16                                     카카오톡 KakaoTalk        커뮤니케이션
# 17                                          Instagram            소셜
# 18                                        네이버 - NAVER       도서/참고자료
# 19                                              배달요기요           식음료
# 20                                 V3 Mobile Plus 2.0            도구
# 21                              Discord - 게이머를 위한 메신저        커뮤니케이션
# 22                               Droid-X III 백신 (기업용)            도구
# 23                   실시간 무료 TV - 지상파, 종합편성, 케이블 무료 티비  동영상 플레이어/편집기
# 24                                                 밴드            소셜
# 25                               Cisco Webex Meetings          비즈니스
# 26                                           Viamaker  동영상 플레이어/편집기
# 27                     번개장터 - 모바일 최대 중고마켓 앱(중고나라,중고차)            쇼핑
# 28     Breaking News : Local & Breaking News Near You         뉴스/잡지
# 29                             이마트 - 매장에서 즐기는 스마트한 혜택        라이프스타일
# 30                                              카카오페이            금융
# 31                            윌라 - 베스트셀러 오디오북&프리미엄 강의            교육
# 32                                       한컴오피스 viewer           생산성
# 33                                 T map - 내비게이션 / 지도      지도/내비게이션
# 34                                           대한민국 청와대           생산성
# 35                                               VITA  동영상 플레이어/편집기
# 36                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 37                                           SNOW 스노우            사진
# 38                                Whale - 네이버 웨일 브라우저        커뮤니케이션
# 39                                            NH스마트뱅킹            금융
# 40                                 QR & 바코드 스캐너 (한국어)           생산성
# 41  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 42                                      네이버 지도, 내비게이션     여행 및 지역정보
# 43                                     Google Play 게임        엔터테인먼트
# 44                                              왓챠플레이        엔터테인먼트
# 45                                              리브메이트            금융
# 46   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 47                                헤이딜러, +100만원 내차팔기 앱           자동차
# 48                                  카카오뱅크 - 같지만 다른 은행            금융
# 49                                    에이블리 - 셀럽마켓 모음앱            쇼핑
#
#                                                  20_9      20_9_gen
# 0                                 ZOOM Cloud Meetings          비즈니스
# 1                                      건강상태 자가진단(교육부)         건강/운동
# 2                                 당근마켓 - 대한민국 1등 동네 앱            쇼핑
# 3                   SPOTV NOW(스포티비 나우) - 프리미엄 스포츠 생중계           스포츠
# 4      X Icon Changer - Customize App Icon & Shortcut         맞춤 설정
# 5                                           TikTok 틱톡  동영상 플레이어/편집기
# 6                                              반올림피자샵           식음료
# 7                                       Netflix(넷플릭스)        엔터테인먼트
# 8                                 하나원큐 - 하나은행 스마트폰 뱅킹            금융
# 9                              쿠팡이츠 - 맛있는 음식을 빠르고 편하게           식음료
# 10                                     카카오톡 KakaoTalk        커뮤니케이션
# 11                    오늘의집 - 1000만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 12                                                 토스            금융
# 13                        Samsung Smart Switch Mobile            도구
# 14                                       Photo widget         맞춤 설정
# 15                                              배달의민족           식음료
# 16                                          Instagram            소셜
# 17                                       쿠팡 (Coupang)            쇼핑
# 18     Space Clean - Junk Clean, Phone Booster Master            도구
# 19                                              CJ더마켓            쇼핑
# 20                                        네이버 - NAVER       도서/참고자료
# 21                            Google Meet - 안전한 화상 회의           생산성
# 22                                    에이블리 - 셀럽마켓 모음앱            쇼핑
# 23                    All Cleaner - 전화기를 더 빨리 작동시키십시오            도구
# 24                                       한컴오피스 viewer           생산성
# 25                                     V3 Mobile Plus            도구
# 26                                     질병관리본부 예방접종도우미         건강/운동
# 27                             배달요기요 - 할인받아 즐기는 맛집배달앱           식음료
# 28                                 T map - 내비게이션 / 지도      지도/내비게이션
# 29                                     Wish - 쇼핑은 즐겁다            쇼핑
# 30                                 QR & 바코드 스캐너 (한국어)           생산성
# 31                                               올리브영            쇼핑
# 32                   실시간 무료 TV - 지상파, 종합편성, 케이블 무료 티비  동영상 플레이어/편집기
# 33   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 34                      Pinterest (핀터레스트): 수백만개의 아이디어            소셜
# 35                                      네이버 지도, 내비게이션     여행 및 지역정보
# 36                                              롯데홈쇼핑            쇼핑
# 37                     셀렉트숍 무신사 - SELECT SHOP MUSINSA            쇼핑
# 38                                               번개장터            쇼핑
# 39                                            ISP/페이북            금융
# 40                               터치엔 엠백신 for Web(기업용)            금융
# 41  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크, 해외여행, 시외버스, 셔틀      지도/내비게이션
# 42                                               삼성카드            금융
# 43                            신한 쏠(SOL) – 신한은행 스마트폰뱅킹            금융
# 44                                              카카오페이            금융
# 45                                       정부24(구 민원24)           생산성
# 46                       GS SHOP - 당신의 가장 좋은 선택을 만듭니다            쇼핑
# 47                                        KB국민은행 스타뱅킹            금융
# 48                                                 밴드            소셜
# 49                        Discord - 친구와 대화, 영상 채팅, 모임        커뮤니케이션

# %%
fp19
# Out:
#                                                  19_1      19_1_gen  \
# 0                                             국세청 홈택스            도구
# 1                                           TikTok 틱톡  동영상 플레이어/편집기
# 2                                       Netflix(넷플릭스)        엔터테인먼트
# 3                                             NH스마트뱅킹            금융
# 4                                   카카오뱅크 - 같지만 다른 은행            금융
# 5                                      카카오톡 KakaoTalk        커뮤니케이션
# 6                                  V3 Mobile Plus 2.0            도구
# 7                   원더쇼핑:인기쇼핑몰/핫딜/여행쿠폰/웹툰/위메프투어/위메프페이            쇼핑
# 8                                        쿠팡 (Coupang)            쇼핑
# 9                                         네이버 - NAVER       도서/참고자료
# 10                        Samsung Smart Switch Mobile            도구
# 11                                   NAVER VIBE (바이브)        음악/오디오
# 12                                              배달의민족           식음료
# 13                           당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 14               위메프 - 특가대표 (특가 / 쇼핑 / 쇼핑앱 / 쿠폰 / 배송)            쇼핑
# 15                    SODA 소다 - Natural Beauty Camera            사진
# 16                                          Instagram            소셜
# 17                                              뱅크샐러드            금융
# 18                                        KB국민은행 스타뱅킹            금융
# 19                                       한컴오피스 viewer           생산성
# 20                                              배달요기요           식음료
# 21                                                 토스            금융
# 22                                   네이버 파파고 - AI 통번역            도구
# 23                                      네이버 지도, 내비게이션     여행 및 지역정보
# 24                                                 밴드            소셜
# 25                                            SSG.COM            쇼핑
# 26                                           Facebook            소셜
# 27                                 튜브박스 - 음악 동영상 다운로드  동영상 플레이어/편집기
# 28                                     Google Play 게임        엔터테인먼트
# 29              Cut Cut - 사진편집어플, 자동 자르기, 얼굴 스왑 및 스티커            사진
# 30                                          Messenger        커뮤니케이션
# 31   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 32  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 33                                        요리백과 만개의레시피           식음료
# 34                                             스마트위택스            금융
# 35                                              NH콕뱅크            금융
# 36                                       [공식]고속버스 티머니      지도/내비게이션
# 37                                               코레일톡     여행 및 지역정보
# 38                                            ISP/페이북            금융
# 39                                       마켓컬리-내일의 장보기           식음료
# 40                     Ulike유라이크 - 스타일, 고급 필터, 뷰티 카메라            사진
# 41                     오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 42                                           FLO – 플로        음악/오디오
# 43                                              카카오내비      지도/내비게이션
# 44                                           SNOW 스노우            사진
# 45                                      롯데홈쇼핑 – 롯데 ON            쇼핑
# 46                              콴다 - 400만 다운로드 수학 공부앱            교육
# 47                                           삼성 음성 녹음            도구
# 48                                   SERIES - 네이버 시리즈       도서/참고자료
# 49                                서울시 세금납부 - 서울시 STAX            금융
#
#                                                  19_2      19_2_gen  \
# 0                        Magic Booster - 제일 좋아하는 청리도구            도구
# 1                                               배달요기요           식음료
# 2        커넥츠: 무료 공부질문 앱-500만 다운로드 (문제해설, 노하우, 과외, 인강)            교육
# 3                                      카카오톡 KakaoTalk        커뮤니케이션
# 4      Super Junk Cleaner - 휴대폰 쿨러, 안드로이드 클리너, 배터리 절약            도구
# 5                                       네이버 지도, 내비게이션     여행 및 지역정보
# 6                                  V3 Mobile Plus 2.0            도구
# 7                                         네이버 - NAVER       도서/참고자료
# 8                                             NH스마트뱅킹            금융
# 9                         Samsung Smart Switch Mobile            도구
# 10                                       쿠팡 (Coupang)            쇼핑
# 11                                       한컴오피스 viewer           생산성
# 12                               T map 택시 - 티맵택시,T맵택시      지도/내비게이션
# 13                                                나침반            도구
# 14                                          TikTok 틱톡  동영상 플레이어/편집기
# 15                                  카카오뱅크 - 같지만 다른 은행            금융
# 16                           당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 17                                      Netflix(넷플릭스)        엔터테인먼트
# 18                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 19                                          Instagram            소셜
# 20                    SODA 소다 - Natural Beauty Camera            사진
# 21                                     Google Play 게임        엔터테인먼트
# 22                                            국세청 홈택스            도구
# 23                                              배달의민족           식음료
# 24                                      BNK부산은행 모바일뱅킹            금융
# 25   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 26                                                 밴드            소셜
# 27                                      Total Cleaner            도구
# 28                                              Intra            도구
# 29                                                 토스            금융
# 30                                   네이버 파파고 - AI 통번역            도구
# 31  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 32                                               코레일톡     여행 및 지역정보
# 33                                              NH콕뱅크            금융
# 34                                           Facebook            소셜
# 35               위메프 - 특가대표 (특가 / 쇼핑 / 쇼핑앱 / 쿠폰 / 배송)            쇼핑
# 36                                 Puffin Web Browser        커뮤니케이션
# 37                              다방 - 대한민국 부동산 매물 최다보유    부동산/홈 인테리어
# 38                     오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 39                                       마켓컬리-내일의 장보기           식음료
# 40                                            SSG.COM            쇼핑
# 41                             에브리타임 - 시간표 & 대학교 커뮤니티            소셜
# 42                                          Messenger        커뮤니케이션
# 43                                            ISP/페이북            금융
# 44                 미세미세 - 미세먼지, WHO기준, 알람, 위젯, 날씨, 지도            날씨
# 45                                              뱅크샐러드            금융
# 46                                           SNOW 스노우            사진
# 47               Smart Radio FM – 무료 음악, 인터넷 & FM 라디오        음악/오디오
# 48                                               삼성닷컴            쇼핑
# 49                                       [공식]고속버스 티머니      지도/내비게이션
#
#                                                 19_3      19_3_gen  \
# 0                                      Samsung Notes           생산성
# 1                                            NH스마트뱅킹            금융
# 2                                           삼성 음성 녹음            도구
# 3                                     카카오톡 KakaoTalk        커뮤니케이션
# 4                                                 토스            금융
# 5                                  카카오뱅크 - 같지만 다른 은행            금융
# 6                                        네이버 - NAVER       도서/참고자료
# 7                        Samsung Smart Switch Mobile            도구
# 8                                 V3 Mobile Plus 2.0            도구
# 9                 미세미세 - 미세먼지, WHO기준, 알람, 위젯, 날씨, 지도            날씨
# 10                                   Samsung Members            도구
# 11                                         바이오인증 공동앱            금융
# 12                                      쿠팡 (Coupang)            쇼핑
# 13                                     BNK부산은행 모바일뱅킹            금융
# 14                                      한컴오피스 viewer           생산성
# 15                                한국투자증권 (스마트폰 계좌개설)            금융
# 16                                                밴드            소셜
# 17                                         TikTok 틱톡  동영상 플레이어/편집기
# 18                                     네이버 지도, 내비게이션     여행 및 지역정보
# 19                              Droid-X III 백신 (기업용)            도구
# 20                                             배달요기요           식음료
# 21                          당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 22                                         Instagram            소셜
# 23                       AliExpress - 스마트한쇼핑, 더즐거운생활            쇼핑
# 24                                          Facebook            소셜
# 25                   SODA 소다 - Natural Beauty Camera            사진
# 26  카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 27                                  네이버 파파고 - AI 통번역            도구
# 28                                           마이 홈플러스        라이프스타일
# 29                                         Messenger        커뮤니케이션
# 30                                       KB국민은행 스타뱅킹            금융
# 31                                    Google Play 게임        엔터테인먼트
# 32                                     Netflix(넷플릭스)        엔터테인먼트
# 33                                             배달의민족           식음료
# 34                                          SNOW 스노우            사진
# 35                                  Amazon Assistant            쇼핑
# 36                                             카카오내비      지도/내비게이션
# 37                                              코레일톡     여행 및 지역정보
# 38                                  카카오페이지 KakaoPage       도서/참고자료
# 39                                                멜론        음악/오디오
# 40                 카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 41                                             뱅크샐러드            금융
# 42              위메프 - 특가대표 (특가 / 쇼핑 / 쇼핑앱 / 쿠폰 / 배송)            쇼핑
# 43                           히든프라이스 - 공동구매 / 특가 / 쇼핑            쇼핑
# 44                                           ISP/페이북            금융
# 45                                             NH콕뱅크            금융
# 46                                              현대카드            금융
# 47                             콴다 - 400만 다운로드 수학 공부앱            교육
# 48                                올원뱅크(All One Bank)            금융
# 49                                  QR 코드 리더/바코드 스캐너            도구
#
#                                                 19_4      19_4_gen  \
# 0                                              배달의민족           식음료
# 1                                  SRT - 수서고속철도(NEW)     여행 및 지역정보
# 2      Super Magic Cleaner - 안드로이드 클리너 휴대폰 쿨러 안티바이러스            도구
# 3                                        네이버 - NAVER       도서/참고자료
# 4                                     카카오톡 KakaoTalk        커뮤니케이션
# 5                                            NH스마트뱅킹            금융
# 6                                            국세청 홈택스            도구
# 7                        Samsung Smart Switch Mobile            도구
# 8                    SODA 소다 - Natural Beauty Camera            사진
# 9                                       쿠팡 (Coupang)            쇼핑
# 10                          당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 11              Turbo VPN –무제한 무료 VPN & 빠른 보안 프록시 접속            도구
# 12                                V3 Mobile Plus 2.0            도구
# 13                                 카카오뱅크 - 같지만 다른 은행            금융
# 14                                     Netflix(넷플릭스)        엔터테인먼트
# 15                                     네이버 지도, 내비게이션     여행 및 지역정보
# 16                                             배달요기요           식음료
# 17                                         TikTok 틱톡  동영상 플레이어/편집기
# 18                                         Instagram            소셜
# 19                                               CGV        엔터테인먼트
# 20                    Ulike유라이크 - 스타일, 고급 필터, 뷰티 카메라            사진
# 21                                           4shared        엔터테인먼트
# 22                                          Facebook            소셜
# 23                                                토스            금융
# 24                                  카카오페이지 KakaoPage       도서/참고자료
# 25                               일기 예보 2020 - 실시간 날씨            날씨
# 26  카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 27                                                밴드            소셜
# 28                                     메가박스(MEGABOX)        엔터테인먼트
# 29                 카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 30                                           ISP/페이북            금융
# 31                                             롯데시네마        엔터테인먼트
# 32                                    Google Play 게임        엔터테인먼트
# 33                                             카카오내비      지도/내비게이션
# 34                                          SNOW 스노우            사진
# 35                                         Messenger        커뮤니케이션
# 36                                      한컴오피스 viewer           생산성
# 37                                  네이버 파파고 - AI 통번역            도구
# 38                                              코레일톡     여행 및 지역정보
# 39                             콴다 - 400만 다운로드 수학 공부앱            교육
# 40                           날씨 오늘 - 라이브일기 예보 앱 2020            날씨
# 41                         Coreader- QR 코드 및 바코드 스캐너        엔터테인먼트
# 42                                     Samsung Notes           생산성
# 43                   challa NEON: 인스타 틱톡 비디오 스토리 만들기        예술/디자인
# 44              Smart Radio FM – 무료 음악, 인터넷 & FM 라디오        음악/오디오
# 45                                         My oksusu  동영상 플레이어/편집기
# 46                                     롯데홈쇼핑 – 롯데 ON            쇼핑
# 47                                                멜론        음악/오디오
# 48                                           다이소 멤버십        라이프스타일
# 49                                      [공식]고속버스 티머니      지도/내비게이션
#
#                                                 19_5      19_5_gen  ...  \
# 0                                           Snapchat            소셜  ...
# 1                               i-ONE Bank - IBK기업은행            금융  ...
# 2                                            국세청 홈택스            도구  ...
# 3                                              배달의민족           식음료  ...
# 4                                        네이버 - NAVER       도서/참고자료  ...
# 5                        Samsung Smart Switch Mobile            도구  ...
# 6                                일기 예보 2020 - 실시간 날씨            날씨  ...
# 7                                            NH스마트뱅킹            금융  ...
# 8                                                 밴드            소셜  ...
# 9                           당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑  ...
# 10                                      쿠팡 (Coupang)            쇼핑  ...
# 11                                    카카오톡 KakaoTalk        커뮤니케이션  ...
# 12                                V3 Mobile Plus 2.0            도구  ...
# 13                                           4shared        엔터테인먼트  ...
# 14                                         TikTok 틱톡  동영상 플레이어/편집기  ...
# 15                                                토스            금융  ...
# 16                                 SRT - 수서고속철도(NEW)     여행 및 지역정보  ...
# 17                                             배달요기요           식음료  ...
# 18                                     Samsung Notes           생산성  ...
# 19                                         Instagram            소셜  ...
# 20                   SODA 소다 - Natural Beauty Camera            사진  ...
# 21                                 카카오뱅크 - 같지만 다른 은행            금융  ...
# 22                                     네이버 지도, 내비게이션     여행 및 지역정보  ...
# 23                                           다이소 멤버십        라이프스타일  ...
# 24  카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보  ...
# 25                                T map - 내비게이션 / 지도      지도/내비게이션  ...
# 26                                         UNIQLO KR        라이프스타일  ...
# 27                                          삼성 음성 녹음            도구  ...
# 28                                          Facebook            소셜  ...
# 29                    Baby Maker: predicts baby face        엔터테인먼트  ...
# 30                                      한컴오피스 viewer           생산성  ...
# 31                                  네이버 파파고 - AI 통번역            도구  ...
# 32                          Baby Filter : Baby Photo            사진  ...
# 33                                         Messenger        커뮤니케이션  ...
# 34                    Ulike유라이크 - 스타일, 고급 필터, 뷰티 카메라            사진  ...
# 35                                     Netflix(넷플릭스)        엔터테인먼트  ...
# 36                                          SNOW 스노우            사진  ...
# 37                 카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션  ...
# 38                                              현대카드            금융  ...
# 39                                             NH콕뱅크            금융  ...
# 40              위메프 - 특가대표 (특가 / 쇼핑 / 쇼핑앱 / 쿠폰 / 배송)            쇼핑  ...
# 41                                              인천e음            금융  ...
# 42                                           ISP/페이북            금융  ...
# 43                                     롯데홈쇼핑 – 롯데 ON            쇼핑  ...
# 44                                             카카오내비      지도/내비게이션  ...
# 45                                    Google Play 게임        엔터테인먼트  ...
# 46                                 이마트몰 – emart mall            쇼핑  ...
# 47                                      마켓컬리-내일의 장보기           식음료  ...
# 48                                              코레일톡     여행 및 지역정보  ...
# 49                                   Samsung Members            도구  ...
#
#                                                  19_8      19_8_gen  \
# 0                                  Google Play AR 서비스            도구
# 1                           T연락처 - 주소록 실시간 백업, 114 검색            도구
# 2                                           홈플러스 더 클럽            쇼핑
# 3                                  V3 Mobile Plus 2.0            도구
# 4                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 5                                               배달요기요           식음료
# 6                                   SRT - 수서고속철도(NEW)     여행 및 지역정보
# 7                                        쿠팡 (Coupang)            쇼핑
# 8                                       네이버 지도, 내비게이션     여행 및 지역정보
# 9                                  T map - 내비게이션 / 지도      지도/내비게이션
# 10                                           Facebook            소셜
# 11                                           타임커머스 티몬            쇼핑
# 12                                              카카오내비      지도/내비게이션
# 13                                     Google Play 게임        엔터테인먼트
# 14                                            4shared        엔터테인먼트
# 15                                     Wish - 쇼핑은 즐겁다            쇼핑
# 16                                           FLO – 플로        음악/오디오
# 17                                          TikTok 틱톡  동영상 플레이어/편집기
# 18                                              해피포인트        라이프스타일
# 19                     Ulike유라이크 - 스타일, 고급 필터, 뷰티 카메라            사진
# 20                                              NH콕뱅크            금융
# 21                                          Messenger        커뮤니케이션
# 22                                        KB국민은행 스타뱅킹            금융
# 23                                   카카오페이지 KakaoPage       도서/참고자료
# 24                                      롯데홈쇼핑 – 롯데 ON            쇼핑
# 25                                       [공식]고속버스 티머니      지도/내비게이션
# 26                         아이디어스(idus) - 핸드메이드/수공예 장터            쇼핑
# 27                                              NH멤버스        라이프스타일
# 28                                                 멜론        음악/오디오
# 29                                            모바일 관세청          비즈니스
# 30                                               삼성카드            금융
# 31                                              뱅크샐러드            금융
# 32                                               현대카드            금융
# 33               위메프 - 특가대표 (특가 / 쇼핑 / 쇼핑앱 / 쿠폰 / 배송)            쇼핑
# 34                             쿠팡이츠 - 맛있는 음식을 빠르고 편하게           식음료
# 35  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 36                     번개장터 - 모바일 최대 중고마켓 앱(중고나라,중고차)            쇼핑
# 37                                          바이오인증 공동앱            금융
# 38                                               올리브영            쇼핑
# 39                                          Google 번역            도구
# 40                                              카카오페이            금융
# 41                                                 토스            금융
# 42                               T map 택시 - 티맵택시,T맵택시      지도/내비게이션
# 43                             네이버 웹툰 - Naver Webtoon            만화
# 44     야놀자 - 국내 및 해외 호텔, 모텔, 펜션, 게하, 레저/티켓, 최대 80% 할인     여행 및 지역정보
# 45                                             KB국민카드            금융
# 46                                          CJ대한통운 택배        라이프스타일
# 47                                             Mi Fit         건강/운동
# 48                   Most - 올인원 카라이프 플랫폼 (SK네트웍스 모스트)      지도/내비게이션
# 49                                     롯데 ON - 롯데하이마트            쇼핑
#
#                                                  19_9      19_9_gen  \
# 0                                                  토스            금융
# 1                                  (New) 우리은행 우리WON뱅킹            금융
# 2                            wavve(웨이브) - 재미의 파도를 타다!        엔터테인먼트
# 3                                             스마트주택금융            금융
# 4                                      VG 기업용 SDK 2.0            도구
# 5                                      카카오톡 KakaoTalk        커뮤니케이션
# 6                                           Instagram            소셜
# 7                         Samsung Smart Switch Mobile            도구
# 8                                         네이버 - NAVER       도서/참고자료
# 9                                  V3 Mobile Plus 2.0            도구
# 10                           당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 11                                      네이버 지도, 내비게이션     여행 및 지역정보
# 12                                           삼성 음성 녹음            도구
# 13                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 14                                              배달요기요           식음료
# 15                                    어카운트인포-계좌정보통합관리            금융
# 16                                     Wish - 쇼핑은 즐겁다            쇼핑
# 17                                 T map - 내비게이션 / 지도      지도/내비게이션
# 18                                      Netflix(넷플릭스)        엔터테인먼트
# 19                                          TikTok 틱톡  동영상 플레이어/편집기
# 20                                              배달의민족           식음료
# 21                                           Facebook            소셜
# 22                                            NH스마트뱅킹            금융
# 23   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 24                                       쿠팡 (Coupang)            쇼핑
# 25                                                 밴드            소셜
# 26                                          Messenger        커뮤니케이션
# 27                                  SRT - 수서고속철도(NEW)     여행 및 지역정보
# 28                                              카카오내비      지도/내비게이션
# 29                            신한 쏠(SOL) – 신한은행 스마트폰뱅킹            금융
# 30                                     Google Play 게임        엔터테인먼트
# 31                                               코레일톡     여행 및 지역정보
# 32                                 음악바다 - 빠른 음악다운 플레이        라이프스타일
# 33                    SODA 소다 - Natural Beauty Camera            사진
# 34                     Ulike유라이크 - 스타일, 고급 필터, 뷰티 카메라            사진
# 35                                  카카오뱅크 - 같지만 다른 은행            금융
# 36                                            4shared        엔터테인먼트
# 37  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 38                                   네이버 파파고 - AI 통번역            도구
# 39                                           SNOW 스노우            사진
# 40                                      롯데홈쇼핑 – 롯데 ON            쇼핑
# 41                               i-ONE Bank - IBK기업은행            금융
# 42                                                 멜론        음악/오디오
# 43                                            ISP/페이북            금융
# 44                                          바이오인증 공동앱            금융
# 45                                          Google 번역            도구
# 46                                       한컴오피스 viewer           생산성
# 47                                       [공식]고속버스 티머니      지도/내비게이션
# 48                                        KB국민은행 스타뱅킹            금융
# 49                                              뱅크샐러드            금융
#
#                                                 19_10   19_10_gen  \
# 0                                  (New) 우리은행 우리WON뱅킹          금융
# 1                                            SNOW 스노우          사진
# 2                                                  토스          금융
# 3                                         KB국민은행 스타뱅킹          금융
# 4                            당근마켓 - 우리 동네 중고 직거래 벼룩장터          쇼핑
# 5                                      Wish - 쇼핑은 즐겁다          쇼핑
# 6                           사용자 휴대폰 도우미 - Windows와 연결         생산성
# 7                                     어카운트인포-계좌정보통합관리          금융
# 8                         Samsung Smart Switch Mobile          도구
# 9                                           Instagram          소셜
# 10                                       쿠팡 (Coupang)          쇼핑
# 11                                            NH스마트뱅킹          금융
# 12                                      네이버 지도, 내비게이션   여행 및 지역정보
# 13                                              배달의민족         식음료
# 14                                 V3 Mobile Plus 2.0          도구
# 15                                              배달요기요         식음료
# 16                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크    지도/내비게이션
# 17                               Chrome: 빠르고 안전한 브라우저      커뮤니케이션
# 18                                        네이버 - NAVER     도서/참고자료
# 19                                              Gmail      커뮤니케이션
# 20                                  SRT - 수서고속철도(NEW)   여행 및 지역정보
# 21                                          바이오인증 공동앱          금융
# 22                                      Netflix(넷플릭스)      엔터테인먼트
# 23                           wavve(웨이브) - 재미의 파도를 타다!      엔터테인먼트
# 24                              Google TTS(텍스트 음성 변환)          도구
# 25                                       한컴오피스 viewer         생산성
# 26   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )   여행 및 지역정보
# 27                                            APT2you  부동산/홈 인테리어
# 28                               터치엔 엠백신 for Web(기업용)          금융
# 29                                  ANT Radio Service      커뮤니케이션
# 30                                 T map - 내비게이션 / 지도    지도/내비게이션
# 31                     Ulike유라이크 - 스타일, 고급 필터, 뷰티 카메라          사진
# 32                                   네이버 파파고 - AI 통번역          도구
# 33                    SODA 소다 - Natural Beauty Camera          사진
# 34                                               코레일톡   여행 및 지역정보
# 35  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...  부동산/홈 인테리어
# 36                                            모바일 관세청        비즈니스
# 37                               ANT+ Plugins Service       건강/운동
# 38                            신한 쏠(SOL) – 신한은행 스마트폰뱅킹          금융
# 39                                      롯데홈쇼핑 – 롯데 ON          쇼핑
# 40                                 Flipboard Briefing       뉴스/잡지
# 41                                                 밴드          소셜
# 42                  Bigfoot: 수많은 게임들을 지원하는 게임 어시스턴트 앱          도구
# 43                                   NAVER VIBE (바이브)      음악/오디오
# 44                                  카카오뱅크 - 같지만 다른 은행          금융
# 45                     오늘의집 - 700만이 선택한 No.1 인테리어 필수앱  부동산/홈 인테리어
# 46                                            디바이스 케어          도구
# 47                                     Google Play 게임      엔터테인먼트
# 48                                    에이블리 - 셀럽마켓 모음앱          쇼핑
# 49                               i-ONE Bank - IBK기업은행          금융
#
#                                                19_11   19_11_gen  \
# 0                          사용자 휴대폰 도우미 - Windows와 연결         생산성
# 1                                                 토스          금융
# 2                                      Samsung Notes         생산성
# 3                                 (New) 우리은행 우리WON뱅킹          금융
# 4                                     Wish - 쇼핑은 즐겁다          쇼핑
# 5                                    에이블리 - 셀럽마켓 모음앱          쇼핑
# 6                                          Instagram          소셜
# 7                           당근마켓 - 우리 동네 중고 직거래 벼룩장터          쇼핑
# 8                                              NH콕뱅크          금융
# 9                         트립스토어 - 해외 패키지 & 에어텔 특가 비교   여행 및 지역정보
# 10                                     네이버 지도, 내비게이션   여행 및 지역정보
# 11                       Samsung Smart Switch Mobile          도구
# 12                                  NAVER VIBE (바이브)      음악/오디오
# 13                                           NH스마트뱅킹          금융
# 14                                V3 Mobile Plus 2.0          도구
# 15                                      쿠팡 (Coupang)          쇼핑
# 16                                                밴드          소셜
# 17                                            디지털 웰빙          도구
# 18                                     Netflix(넷플릭스)      엔터테인먼트
# 19                                           국세청 홈택스          도구
# 20  카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )   여행 및 지역정보
# 21                                       네이버 - NAVER     도서/참고자료
# 22                                         Google 렌즈          도구
# 23                                             배달의민족         식음료
# 24                 카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크    지도/내비게이션
# 25                              터치엔 엠백신 for Web(기업용)          금융
# 26                                           모바일 관세청        비즈니스
# 27                             Google TTS(텍스트 음성 변환)          도구
# 28                                             배달요기요         식음료
# 29                                                지도   여행 및 지역정보
# 30                                             해피포인트      라이프스타일
# 31                                       KB국민은행 스타뱅킹          금융
# 32                                           ISP/페이북          금융
# 33                                T map - 내비게이션 / 지도    지도/내비게이션
# 34                                 ANT Radio Service      커뮤니케이션
# 35                                Flipboard Briefing       뉴스/잡지
# 36                                    카카오톡 KakaoTalk      커뮤니케이션
# 37                              ANT+ Plugins Service       건강/운동
# 38                                              코레일톡   여행 및 지역정보
# 39                                  네이버 파파고 - AI 통번역          도구
# 40                    오늘의집 - 700만이 선택한 No.1 인테리어 필수앱  부동산/홈 인테리어
# 41                    셀렉트숍 무신사 - SELECT SHOP MUSINSA          쇼핑
# 42                           알바몬 - 알바 채용 구인구직 취업정보검색        비즈니스
# 43                                             카카오내비    지도/내비게이션
# 44                           신한 쏠(SOL) – 신한은행 스마트폰뱅킹          금융
# 45                                 카카오뱅크 - 같지만 다른 은행          금융
# 46                                                멜론      음악/오디오
# 47                                 SRT - 수서고속철도(NEW)   여행 및 지역정보
# 48                        Samsung Experience Service          도구
# 49                                      한컴오피스 viewer         생산성
#
#                                                 19_12     19_12_gen
# 0                          트립스토어 - 해외 패키지 & 에어텔 특가 비교     여행 및 지역정보
# 1                                       Netflix(넷플릭스)        엔터테인먼트
# 2                                           Instagram            소셜
# 3                            당근마켓 - 우리 동네 중고 직거래 벼룩장터            쇼핑
# 4                                  (New) 우리은행 우리WON뱅킹            금융
# 5                                               배달의민족           식음료
# 6                                               배달요기요           식음료
# 7                                         네이버 - NAVER       도서/참고자료
# 8                                        쿠팡 (Coupang)            쇼핑
# 9                                       네이버 지도, 내비게이션     여행 및 지역정보
# 10                                       YouTube Kids        엔터테인먼트
# 11                                     카카오톡 KakaoTalk        커뮤니케이션
# 12                                               팝콘티비        엔터테인먼트
# 13                  카카오 T - 택시, 대리운전, 주차, 내비, 카풀, 바이크      지도/내비게이션
# 14                        Samsung Smart Switch Mobile            도구
# 15                                TikTok Wall Picture  동영상 플레이어/편집기
# 16                                                 토스            금융
# 17                                 V3 Mobile Plus 2.0            도구
# 18                           wavve(웨이브) - 재미의 파도를 타다!        엔터테인먼트
# 19                    티빙(TVING) - 실시간TV, 방송VOD, 영화VOD  동영상 플레이어/편집기
# 20                                  카카오뱅크 - 같지만 다른 은행            금융
# 21                                     Wish - 쇼핑은 즐겁다            쇼핑
# 22   카카오맵 - 대한민국 No.1 지도앱 ( 지도 / 내비게이션 / 대중교통 / 로드뷰 )     여행 및 지역정보
# 23                                      롯데홈쇼핑 – 롯데 ON            쇼핑
# 24                     Ulike유라이크 - 스타일, 고급 필터, 뷰티 카메라            사진
# 25                                           SNOW 스노우            사진
# 26                                          TikTok 틱톡  동영상 플레이어/편집기
# 27                                    에이블리 - 셀럽마켓 모음앱            쇼핑
# 28                                                 밴드            소셜
# 29                                 T map - 내비게이션 / 지도      지도/내비게이션
# 30                                               코레일톡     여행 및 지역정보
# 31                                           Facebook            소셜
# 32                                     Google Play 게임        엔터테인먼트
# 33                                            NH스마트뱅킹            금융
# 34                     오늘의집 - 700만이 선택한 No.1 인테리어 필수앱    부동산/홈 인테리어
# 35     야놀자 - 국내 및 해외 호텔, 모텔, 펜션, 게하, 레저/티켓, 최대 80% 할인     여행 및 지역정보
# 36                    SODA 소다 - Natural Beauty Camera            사진
# 37                                   SERIES - 네이버 시리즈       도서/참고자료
# 38                                            ISP/페이북            금융
# 39                                            국세청 홈택스            도구
# 40                                              카카오내비      지도/내비게이션
# 41                                            4shared        엔터테인먼트
# 42                                   네이버 파파고 - AI 통번역            도구
# 43                                       [공식]고속버스 티머니      지도/내비게이션
# 44  직방 - 2,800만명이 선택한 No.1 부동산 앱(아파트,분양,원룸,오피스텔,빌라...    부동산/홈 인테리어
# 45                                      Samsung Notes           생산성
# 46            여기어때 - 호텔, 모텔, 펜션, 캠핑, 게하, 액티비티 최저가 예약!     여행 및 지역정보
# 47                                          Messenger        커뮤니케이션
# 48                                알바천국- 알바 구인구직 포털서비스          비즈니스
# 49                         PASS by SK TELECOM(구, T인증)            금융
#
# [50 rows x 24 columns]

# %%
# 19,20년 전체 데이터프레임 월별 장르별 점수 데이터프레임 
def score_df(df,month,yr):
    tmp = [i for i in list(df) if 'gen' in i]
    genre_list = list(set(np.array(df[tmp]).reshape(len(tmp)*50,)))
    genre_yr = []
    for i in tmp:
        genre_dic = {key: 0 for key in dict.fromkeys(genre_list).keys()}
        score = 50
        for j in df.dropna()[i]:
            genre_dic[j] = genre_dic[j]+score
            score -= 1
        genre_yr.append(genre_dic)

    col = []
    for i in range(month):
        col.append(f'{yr}_'+str(i+1))

    app_yr = pd.DataFrame(genre_yr)
    app_yr = app_yr.T
    app_yr.columns = col
    app_yr.drop([app_yr.index[0]],inplace=True)
    
    return app_yr
    
    
# 19년도 1~10월 평균을 기준으로 설정
def standard_df(df,month):
    if month == 10:
        standard_19 = df[['19_1','19_2','19_3','19_4','19_5','19_6','19_7','19_8','19_9','19_10']]
        standard_19 = standard_19.reset_index()
        standard_19 = standard_19.set_index('index')

        standard_19['average'] = 0.000
        for i in range(len(standard_19)):
            total = 0
            for j in range(0,10):
                total += standard_19.iloc[i][j]
            standard_19['average'][i] = total.mean()

        standard_19 = standard_19[['average']]
        standard_19 = standard_19.reset_index()
        genre = list(standard_19['index'])
        std_df = standard_19.set_index('index')
    return genre,std_df


# 증감율 계산 : (시점값 - 기준값) / 기준값
# 19년은 12월까지이므로 12입력하면 19년도 데이터프레임 반환    
def rate_df(genre,std_df,df,month):
    if month == 12:
        app_yr = df[['19_11','19_12']]
        col = []
        for i in range(11,13):
            col.append(str(i)+'월')

        app_yr = app_yr.reset_index()

        for i in range(len(col)):
            app_yr[col[i]] = 0.000

        for i in range(len(app_yr)):
            base = app_yr['index'][i]
            if base in genre:
                idx = genre.index(base)
                base = std_df.iloc[idx]['average']
            else:
                base = 1.0
            for j in range(2,4):
                if base == 0:
                    value = 0.0
                else:
                    value = (float(app_yr.iloc[i][j]) - base) / base
                app_yr[col[j-2]][i] = value

        app_yr = app_yr[['index','11월','12월']]
        app_yr.columns = ['genre','11월','12월']

        app_fig = pd.DataFrame()
        genre_lst, val_tmp, mth_tmp = [], [], []
        for i in range(len(app_yr.columns)-1):
            genre_lst.append(list(app_yr['genre']))
            val_tmp.append(app_yr.iloc[:,i+1].tolist())
            for j in range(len(app_yr)):
                mth_tmp.append(app_yr.columns[i+1])

        genre_lst = [y for x in genre_lst for y in x]
        val_tmp = [y for x in val_tmp for y in x]

        app_fig['genre'] = genre_lst
        app_fig['month'] = mth_tmp
        app_fig['value'] = val_tmp
        return app_fig
                      
    if month == 9:
        app_yr = df        
        col = []
        for i in range(1,10):
            col.append(str(i)+'월')

        app_yr = app_yr.reset_index()

        for i in range(len(col)):
            app_yr[col[i]] = 0.000

        for i in range(len(app_yr)):
            base = app_yr['index'][i]
            if base in genre:
                idx = genre.index(base)
                base = std_df.iloc[idx]['average']
            else:
                base = 1.0
            for j in range(1,10):
                if base == 0:
                    value = 0.0
                else:
                    value = ((float(app_yr.iloc[i][j]) - base) / base)*100
                app_yr[col[j-1]][i] = value

        app_yr = app_yr[['index','1월','2월','3월','4월','5월','6월','7월','8월','9월']]
        app_yr.columns = ['genre','1월','2월','3월','4월','5월','6월','7월','8월','9월']

        app_fig = pd.DataFrame()
        genre_lst, val_tmp, mth_tmp = [], [], []
        for i in range(len(app_yr.columns)-1):
            genre_lst.append(list(app_yr['genre']))
            val_tmp.append(app_yr.iloc[:,i+1].tolist())
            for j in range(len(app_yr)):
                mth_tmp.append(app_yr.columns[i+1])

        genre_lst = [y for x in genre_lst for y in x]
        val_tmp = [y for x in val_tmp for y in x]

        app_fig['genre'] = genre_lst
        app_fig['month'] = mth_tmp
        app_fig['value'] = val_tmp    
        return app_fig

    #app19_graph = pd.concat([pay_playstore_19_graph,pay_playstore_19_fig], axis = 0)

# %%
score_19 = score_df(fp19,12,19)
genre,std_df = standard_df(score_df(fp19,12,19),10)
rate_19_grph = rate_df(genre,std_df,score_19,12)
# Out:
# <ipython-input-28-e7c0cd21913a>:38: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-28-e7c0cd21913a>:73: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 19년 1~10월을 기준지표로 했을 때 나타난 19년 11~12월 증감율
rate_19_grph
# Out:
#            genre month     value
# 0             기타   11월 -1.000000
# 1        도서/참고자료   11월 -0.876380
# 2      여행 및 지역정보   11월 -0.834555
# 3             소셜   11월 -0.894799
# 4            자동차   11월 -1.000000
# 5         예술/디자인   11월 -1.000000
# 6            식음료   11월 -0.883049
# 7         라이프스타일   11월 -1.000000
# 8           비즈니스   11월 -0.947368
# 9         음악/오디오   11월 -1.000000
# 10            도구   11월 -0.951675
# 11            날씨   11월 -1.000000
# 12        커뮤니케이션   11월 -0.933227
# 13            만화   11월 -1.000000
# 14         뉴스/잡지   11월 -1.000000
# 15            쇼핑   11월 -0.881356
# 16        엔터테인먼트   11월 -0.787429
# 17            교육   11월 -1.000000
# 18         건강/운동   11월 -1.000000
# 19            사진   11월 -0.885563
# 20      지도/내비게이션   11월 -0.875208
# 21           생산성   11월 -0.986450
# 22  동영상 플레이어/편집기   11월 -0.747899
# 23    부동산/홈 인테리어   11월 -0.905983
# 24            기타   12월 -1.062500
# 25       도서/참고자료   12월 -1.001935
# 26     여행 및 지역정보   12월 -1.000874
# 27            소셜   12월 -1.001058
# 28           자동차   12월 -1.090909
# 29        예술/디자인   12월 -1.142857
# 30           식음료   12월 -1.001160
# 31        라이프스타일   12월 -1.004237
# 32          비즈니스   12월 -1.024931
# 33        음악/오디오   12월 -1.005000
# 34            도구   12월 -1.000523
# 35            날씨   12월 -1.004785
# 36        커뮤니케이션   12월 -1.001484
# 37            만화   12월 -1.142857
# 38         뉴스/잡지   12월 -1.100000
# 39            쇼핑   12월 -1.000622
# 40        엔터테인먼트   12월 -1.000900
# 41            교육   12월 -1.015152
# 42         건강/운동   12월 -1.035714
# 43            사진   12월 -1.001559
# 44      지도/내비게이션   12월 -1.001456
# 45           생산성   12월 -1.002673
# 46  동영상 플레이어/편집기   12월 -1.002095
# 47    부동산/홈 인테리어   12월 -1.003872

# %%
score_20 = score_df(fp20,9,20)
rate_20_grph = rate_df(genre,std_df,score_20,9)
# Out:
# <ipython-input-28-e7c0cd21913a>:117: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
graph_ = pd.concat([rate_19_grph,rate_20_grph],axis=0)
graph_
# Out:
#           genre month       value
# 0      지도/내비게이션   11월   -0.875208
# 1         뉴스/잡지   11월   -1.000000
# 2    부동산/홈 인테리어   11월   -0.905983
# 3          비즈니스   11월   -0.947368
# 4           자동차   11월   -1.000000
# ..          ...   ...         ...
# 220   여행 및 지역정보    9월  -96.649215
# 221          사진    9월 -100.000000
# 222      커뮤니케이션    9월  -93.481717
# 223          교육    9월 -100.000000
# 224         생산성    9월  -78.319783
#
# [273 rows x 3 columns]

# %%
def float_genre(genre):
    tmp = graph_[(graph_.genre ==f'{genre}')]
    minMaxScaler = MinMaxScaler()
    scaled_val = minMaxScaler.fit_transform(np.array(tmp['value']).reshape(-1,1)).tolist()
    plt.plot(tmp.month,scaled_val, label=f'{genre}앱 관심도 증감율')
    plt.title('앱 사용량 랭킹에 따른 관심도 증감률 추이')
    plt.legend(fontsize=8)
    plt.rc('font',family='AppleGothic')
    plt.rc('axes', unicode_minus=False)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
minMaxScaler = MinMaxScaler()
health = minMaxScaler.fit_transform(np.array(graph_[(graph_.genre =='건강/운동')]['value']).reshape(-1,1)).tolist()
health = np.ravel(health).tolist()
social = minMaxScaler.fit_transform(np.array(graph_[(graph_.genre =='소셜')]['value']).reshape(-1,1)).tolist()
social = np.ravel(social).tolist()

# %%
float_genre('건강/운동')
float_genre('소셜')
float_genre('의료')

# %%
float_genre('건강/운동')
float_genre('소셜')
float_genre('의료')
float_genre('여행 및 지역정보')

# %%
# 소셜은 사용량이 매우 크므로 다른 어플의 추이를 더 보기 위해 제거해보자
graph_wo_social = graph_[(graph_.genre !='소셜')].reset_index(drop=True)
fig = px.bar(graph_wo_social, x='genre',y='value',color='genre',animation_frame='month',animation_group='genre',range_y=[min(graph_wo_social['value'])-5, max(graph_wo_social['value'])+5])
fig.show()
# Out:
# <div>                            <div id="b2ca942f-fb2b-4114-b51a-f55e5c751e5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b2ca942f-fb2b-4114-b51a-f55e5c751e5b")) {                    Plotly.newPlot(                        "b2ca942f-fb2b-4114-b51a-f55e5c751e5b",                        [{"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\uc0ac\uc9c4"], "legendgroup": "\uc0ac\uc9c4", "marker": {"color": "#636efa"}, "name": "\uc0ac\uc9c4", "offsetgroup": "\uc0ac\uc9c4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc0ac\uc9c4"], "xaxis": "x", "y": [-0.8855633802816901], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\ube44\uc988\ub2c8\uc2a4"], "legendgroup": "\ube44\uc988\ub2c8\uc2a4", "marker": {"color": "#EF553B"}, "name": "\ube44\uc988\ub2c8\uc2a4", "offsetgroup": "\ube44\uc988\ub2c8\uc2a4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ube44\uc988\ub2c8\uc2a4"], "xaxis": "x", "y": [-0.9473684210526315], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\uac74\uac15/\uc6b4\ub3d9"], "legendgroup": "\uac74\uac15/\uc6b4\ub3d9", "marker": {"color": "#00cc96"}, "name": "\uac74\uac15/\uc6b4\ub3d9", "offsetgroup": "\uac74\uac15/\uc6b4\ub3d9", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uac74\uac15/\uc6b4\ub3d9"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4"], "legendgroup": "\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4", "marker": {"color": "#ab63fa"}, "name": "\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4", "offsetgroup": "\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4"], "xaxis": "x", "y": [-0.905982905982906], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\uad50\uc721"], "legendgroup": "\uad50\uc721", "marker": {"color": "#FFA15A"}, "name": "\uad50\uc721", "offsetgroup": "\uad50\uc721", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uad50\uc721"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\ub0a0\uc528"], "legendgroup": "\ub0a0\uc528", "marker": {"color": "#19d3f3"}, "name": "\ub0a0\uc528", "offsetgroup": "\ub0a0\uc528", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub0a0\uc528"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\uc1fc\ud551"], "legendgroup": "\uc1fc\ud551", "marker": {"color": "#FF6692"}, "name": "\uc1fc\ud551", "offsetgroup": "\uc1fc\ud551", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc1fc\ud551"], "xaxis": "x", "y": [-0.8813559322033898], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\ub9cc\ud654"], "legendgroup": "\ub9cc\ud654", "marker": {"color": "#B6E880"}, "name": "\ub9cc\ud654", "offsetgroup": "\ub9cc\ud654", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub9cc\ud654"], " ...

# %%
# max값이 크게 나타났던 소셜과 스포츠,의료 장르를 제외하고 사용랭킹에 따른 앱 관심도 증감률을 봐보자
graph_wo_ = graph_[(graph_.genre !='소셜') & (graph_.genre !='스포츠')& (graph_.genre !='의료')].reset_index(drop=True)
fig = px.bar(graph_wo_, x='genre',y='value',color='genre',animation_frame='month',animation_group='genre',range_y=[min(graph_wo_['value'])-5, max(graph_wo_['value'])+5])
fig.show()
# Out:
# <div>                            <div id="2dfa3ef8-0ff4-4eae-ad92-c3ff90451e0a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2dfa3ef8-0ff4-4eae-ad92-c3ff90451e0a")) {                    Plotly.newPlot(                        "2dfa3ef8-0ff4-4eae-ad92-c3ff90451e0a",                        [{"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\uc0ac\uc9c4"], "legendgroup": "\uc0ac\uc9c4", "marker": {"color": "#636efa"}, "name": "\uc0ac\uc9c4", "offsetgroup": "\uc0ac\uc9c4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc0ac\uc9c4"], "xaxis": "x", "y": [-0.8855633802816901], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\ube44\uc988\ub2c8\uc2a4"], "legendgroup": "\ube44\uc988\ub2c8\uc2a4", "marker": {"color": "#EF553B"}, "name": "\ube44\uc988\ub2c8\uc2a4", "offsetgroup": "\ube44\uc988\ub2c8\uc2a4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ube44\uc988\ub2c8\uc2a4"], "xaxis": "x", "y": [-0.9473684210526315], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\uac74\uac15/\uc6b4\ub3d9"], "legendgroup": "\uac74\uac15/\uc6b4\ub3d9", "marker": {"color": "#00cc96"}, "name": "\uac74\uac15/\uc6b4\ub3d9", "offsetgroup": "\uac74\uac15/\uc6b4\ub3d9", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uac74\uac15/\uc6b4\ub3d9"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4"], "legendgroup": "\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4", "marker": {"color": "#ab63fa"}, "name": "\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4", "offsetgroup": "\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ubd80\ub3d9\uc0b0/\ud648 \uc778\ud14c\ub9ac\uc5b4"], "xaxis": "x", "y": [-0.905982905982906], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\uad50\uc721"], "legendgroup": "\uad50\uc721", "marker": {"color": "#FFA15A"}, "name": "\uad50\uc721", "offsetgroup": "\uad50\uc721", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uad50\uc721"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\ub0a0\uc528"], "legendgroup": "\ub0a0\uc528", "marker": {"color": "#19d3f3"}, "name": "\ub0a0\uc528", "offsetgroup": "\ub0a0\uc528", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub0a0\uc528"], "xaxis": "x", "y": [-1.0], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\uc1fc\ud551"], "legendgroup": "\uc1fc\ud551", "marker": {"color": "#FF6692"}, "name": "\uc1fc\ud551", "offsetgroup": "\uc1fc\ud551", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\uc1fc\ud551"], "xaxis": "x", "y": [-0.8813559322033898], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "genre=%{x}<br>month=11\uc6d4<br>value=%{y}<extra></extra>", "ids": ["\ub9cc\ud654"], "legendgroup": "\ub9cc\ud654", "marker": {"color": "#B6E880"}, "name": "\ub9cc\ud654", "offsetgroup": "\ub9cc\ud654", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["\ub9cc\ud654"], " ...

# %%
std_df = standard_df(score_df(fp19,12),10)
std_df
# Out:
# <ipython-input-87-c8f81bc25f1e>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   standard_19['average'][i] = total/10
#               average
# index
# 사진               56.8
# 비즈니스              3.8
# 건강/운동             2.8
# 부동산/홈 인테리어       23.4
# 교육                6.6
# 날씨               20.9
# 쇼핑              141.6
# 만화                0.7
# 동영상 플레이어/편집기     35.7
# 지도/내비게이션         60.1
# 도구              182.1
# 도서/참고자료          45.3
# 커뮤니케이션           62.9
# 금융              203.7
# 기타                1.6
# 음악/오디오           20.0
# 뉴스/잡지             1.0
# 자동차               1.1
# 예술/디자인            0.7
# 생산성              36.9
# 라이프스타일           23.6
# 식음료              76.1
# 여행 및 지역정보        95.5
# 엔터테인먼트           87.5
